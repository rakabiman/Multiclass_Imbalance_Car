# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from mlxtend.classifier import StackingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, balanced_accuracy_score
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, classification_report, precision_recall_curve
from sklearn.model_selection import train_test_split
from imblearn.metrics import geometric_mean_score, sensitivity_score, specificity_score
from xgboost import XGBClassifier
from shaphypetune import BoostRFE
from sklearn.base import BaseEstimator
from sklearn.utils.metaestimators import if_delegate_has_method

import torch
import re, pickle, random, os
import warnings
warnings.filterwarnings('ignore')

from collections import Counter

# %%
def seed_everything(seed=1234):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

RANDOM_STATE = 42
seed_everything(seed=RANDOM_STATE)

# %%
col_names = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'acceptability']
df = pd.read_csv('car.csv', names = col_names)
df.shape
# Out:
# (1728, 7)

# %%
df.head()
# Out:
#   buying  maint doors persons lug_boot safety acceptability
# 0  vhigh  vhigh     2       2    small    low         unacc
# 1  vhigh  vhigh     2       2    small    med         unacc
# 2  vhigh  vhigh     2       2    small   high         unacc
# 3  vhigh  vhigh     2       2      med    low         unacc
# 4  vhigh  vhigh     2       2      med    med         unacc

# %%
df['acceptability'].value_counts()
# Out:
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: acceptability, dtype: int64

# %%
df.isnull().sum()
# Out:
# buying           0
# maint            0
# doors            0
# persons          0
# lug_boot         0
# safety           0
# acceptability    0
# dtype: int64

# %%
df.describe()
# Out:
#        buying  maint doors persons lug_boot safety acceptability
# count    1728   1728  1728    1728     1728   1728          1728
# unique      4      4     4       3        3      3             4
# top     vhigh  vhigh     2       2    small    low         unacc
# freq      432    432   432     576      576    576          1210

# %%
df['buying'] = df['buying'].replace('vhigh', 3)
df['buying'] = df['buying'].replace('high', 2)
df['buying'] = df['buying'].replace('med', 1)
df['buying'] = df['buying'].replace('low', 0)
df['maint'] = df['maint'].replace('vhigh', 3)
df['maint'] = df['maint'].replace('high', 2)
df['maint'] = df['maint'].replace('med', 1)
df['maint'] = df['maint'].replace('low', 0)
df['doors'] = df['doors'].replace('5more', 3)
df['doors'] = df['doors'].replace('4', 2)
df['doors'] = df['doors'].replace('3', 1)
df['doors'] = df['doors'].replace('2', 0)
df['persons'] = df['persons'].replace('more', 2)
df['persons'] = df['persons'].replace('4', 1)
df['persons'] = df['persons'].replace('2', 0)
df['lug_boot'] = df['lug_boot'].replace('big', 2)
df['lug_boot'] = df['lug_boot'].replace('med', 1)
df['lug_boot'] = df['lug_boot'].replace('small', 0)
df['safety'] = df['safety'].replace('high', 2)
df['safety'] = df['safety'].replace('med', 1)
df['safety'] = df['safety'].replace('low', 0)
df['acceptability'] = df['acceptability'].replace('vgood', 3)
df['acceptability'] = df['acceptability'].replace('good', 2)
df['acceptability'] = df['acceptability'].replace('acc', 1)
df['acceptability'] = df['acceptability'].replace('unacc', 0)

df.head()
# Out:
#    buying  maint  doors  persons  lug_boot  safety  acceptability
# 0       3      3      0        0         0       0              0
# 1       3      3      0        0         0       1              0
# 2       3      3      0        0         0       2              0
# 3       3      3      0        0         1       0              0
# 4       3      3      0        0         1       1              0

# %% [markdown]
# # Train and Test Split

# %%
x = df.drop(['acceptability'], axis=1)
y = df['acceptability']

X_train,X_test,y_train,y_test=train_test_split(x, y, train_size=0.8, stratify = y, random_state=100)

# %%
y_train.shape, y_test.shape
# Out:
# ((1382,), (346,))

# %%
y_train.value_counts()/len(y_train)
# Out:
# 0    0.700434
# 1    0.222142
# 2    0.039797
# 3    0.037627
# Name: acceptability, dtype: float64

# %%
y_test.value_counts()/len(y_test)
# Out:
# 0    0.699422
# 1    0.222543
# 2    0.040462
# 3    0.037572
# Name: acceptability, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
Scaler_X = StandardScaler()
X_train = Scaler_X.fit_transform(X_train)
X_test = Scaler_X.transform(X_test)

# %% [markdown]
# # Model Building

# %%
model = list()
precision = list()
recall = list()
F1score = list()
AUCROC = list()
balanced_acc = list()
GMean = list()
sensi = list()
speci = list()

# %%
def test_eval(clf_model, X_test, y_test, algo=None):

    y_prob=clf_model.predict_proba(X_test)
    y_pred=clf_model.predict(X_test)

    print('Confusion Matrix')
    print('='*60)
    print(confusion_matrix(y_test,y_pred),"\n")
    print('Classification Report')
    print('='*60)
    print(classification_report(y_test,y_pred),"\n")
    print('='*60)
    print('AUC-ROC')
    print(roc_auc_score(y_test, y_prob, multi_class='ovr'), "\n")
    print('Balanced Accuracy')
    print(balanced_accuracy_score(y_test, y_pred),"\n")
    print('Geometric Mean Score')
    print(geometric_mean_score(y_test, y_pred, average='macro'),"\n")
    print('Sensitivity')
    print(sensitivity_score(y_test, y_pred, average='macro'),"\n")
    print('Specificity')
    print(specificity_score(y_test, y_pred, average='macro'))
          
    model.append(algo)
    precision.append(precision_score(y_test,y_pred, average='macro'))
    recall.append(recall_score(y_test,y_pred, average='macro'))
    F1score.append(f1_score(y_test,y_pred, average='macro'))
    AUCROC.append(roc_auc_score(y_test, y_prob, multi_class='ovr', average='macro'))
    balanced_acc.append(balanced_accuracy_score(y_test, y_pred))
    GMean.append(geometric_mean_score(y_test, y_pred, average='macro'))
    sensi.append(sensitivity_score(y_test, y_pred, average='macro'))
    speci.append(specificity_score(y_test, y_pred, average='macro'))

# %% [markdown]
# ## Model-1: Logistic Regression

# %%
clf_LR = LogisticRegression(multi_class='ovr', solver='liblinear')
clf_LR.fit(X_train, y_train)
# Out:
# LogisticRegression(multi_class='ovr', solver='liblinear')

# %%
test_eval(clf_LR, X_test, y_test, 'Logistic Regression')
# Out:
# Confusion Matrix
# ============================================================
# [[224  18   0   0]
#  [ 27  50   0   0]
#  [  1  12   1   0]
#  [  0  11   0   2]]
#
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91       242
#            1       0.55      0.65      0.60        77
#            2       1.00      0.07      0.13        14
#            3       1.00      0.15      0.27        13
#
#     accuracy                           0.80       346
#    macro avg       0.86      0.45      0.48       346
# weighted avg       0.82      0.80      0.78       346
#
#
# ============================================================
# AUC-ROC
# 0.9414287702743995
#
# Balanced Accuracy
# 0.45006130233402963
#
# Geometric Mean Score
# 0.6345230796894841
#
# Sensitivity
# 0.45006130233402963
#
# Specificity
# 0.8945882184729768

# %% [markdown]
# ## Model-2: Decision Tree

# %%
clf_DT = DecisionTreeClassifier()
clf_DT.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
test_eval(clf_DT, X_test, y_test, 'Decision Tree')
# Out:
# Confusion Matrix
# ============================================================
# [[239   2   1   0]
#  [  2  73   2   0]
#  [  0   3  11   0]
#  [  0   0   0  13]]
#
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       242
#            1       0.94      0.95      0.94        77
#            2       0.79      0.79      0.79        14
#            3       1.00      1.00      1.00        13
#
#     accuracy                           0.97       346
#    macro avg       0.93      0.93      0.93       346
# weighted avg       0.97      0.97      0.97       346
#
#
# ============================================================
# AUC-ROC
# 0.9593144081434348
#
# Balanced Accuracy
# 0.9303423848878394
#
# Geometric Mean Score
# 0.9588768197949443
#
# Sensitivity
# 0.9303423848878394
#
# Specificity
# 0.9882864313990305

# %% [markdown]
# ## Model-3: Gaussian NB

# %%
clf_NB = GaussianNB()
clf_NB.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
test_eval(clf_NB, X_test, y_test, 'Gaussian NB')
# Out:
# Confusion Matrix
# ============================================================
# [[202  10   1  29]
#  [ 23  18   1  35]
#  [  1   4   0   9]
#  [  0   0   0  13]]
#
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86       242
#            1       0.56      0.23      0.33        77
#            2       0.00      0.00      0.00        14
#            3       0.15      1.00      0.26        13
#
#     accuracy                           0.67       346
#    macro avg       0.40      0.52      0.36       346
# weighted avg       0.76      0.67      0.69       346
#
#
# ============================================================
# AUC-ROC
# 0.8703461421570892
#
# Balanced Accuracy
# 0.5171192443919717
#
# Geometric Mean Score
# 0.6718911453741685
#
# Sensitivity
# 0.5171192443919717
#
# Specificity
# 0.8729857109901451

# %% [markdown]
# ## Model-4: K-Nearest Neighbour

# %%
clf_KNN = KNeighborsClassifier()
clf_KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
test_eval(clf_KNN, X_test, y_test, 'KNN')
# Out:
# Confusion Matrix
# ============================================================
# [[238   4   0   0]
#  [  3  74   0   0]
#  [  0   4  10   0]
#  [  0   2   0  11]]
#
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       242
#            1       0.88      0.96      0.92        77
#            2       1.00      0.71      0.83        14
#            3       1.00      0.85      0.92        13
#
#     accuracy                           0.96       346
#    macro avg       0.97      0.88      0.91       346
# weighted avg       0.96      0.96      0.96       346
#
#
# ============================================================
# AUC-ROC
# 0.9959723067594207
#
# Balanced Accuracy
# 0.8762373989646718
#
# Geometric Mean Score
# 0.9283183231036639
#
# Sensitivity
# 0.8762373989646718
#
# Specificity
# 0.9834947812410637

# %% [markdown]
# ## MODEL-5 Support Vector Classifier

# %%
clf_SVC = SVC(probability=True)
clf_SVC.fit(X_train, y_train)
# Out:
# SVC(probability=True)

# %%
test_eval(clf_SVC, X_test, y_test, 'SVC')
# Out:
# Confusion Matrix
# ============================================================
# [[236   6   0   0]
#  [  1  76   0   0]
#  [  0   3   9   2]
#  [  0   1   0  12]]
#
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       242
#            1       0.88      0.99      0.93        77
#            2       1.00      0.64      0.78        14
#            3       0.86      0.92      0.89        13
#
#     accuracy                           0.96       346
#    macro avg       0.93      0.88      0.90       346
# weighted avg       0.97      0.96      0.96       346
#
#
# ============================================================
# AUC-ROC
# 0.9978953917979918
#
# Balanced Accuracy
# 0.8820384161293253
#
# Geometric Mean Score
# 0.9329503558171994
#
# Sensitivity
# 0.8820384161293253
#
# Specificity
# 0.9868009720472546

# %% [markdown]
# # MODEL-6 XGBoost

# %%
class BoostRFEWrap(BaseEstimator, BoostRFE):

    @if_delegate_has_method(delegate='estimator')
    def predict_proba(self, X):
        return self.predict(X, method='predict_proba')


xgb_params = {'max_depth': (5,10),
          'learning_rate': (0.001, 0.3),
          'n_estimators': (25, 200),
          'reg_alpha' : (0.1, 1),
          'reg_lambda': (0.1, 1),
          'subsample': (0.5,  0.9),
          'colsample_bytree': (0.5,1),
          'min_child_weight': (0,10),
          'gamma': (0,1)}

clf_XGB = BoostRFEWrap(XGBClassifier(), param_grid=xgb_params, importance_type='shap_importances', train_importance=False, min_features_to_select=1, step=1)

# %%
xclf = clf_XGB.fit(X_train, y_train, eval_set=[(X_test, y_test)], early_stopping_rounds=6, verbose=0)
# Out:
# 512 trials detected for ('max_depth', 'learning_rate', 'n_estimators', 'reg_alpha', 'reg_lambda', 'subsample', 'colsample_bytree', 'min_child_weight', 'gamma')
#
# trial: 0001 ### iterations: 00043 ### eval_score: 0.03468
# trial: 0002 ### iterations: 00024 ### eval_score: 0.0578
# trial: 0003 ### iterations: 00027 ### eval_score: 0.07803
# trial: 0004 ### iterations: 00025 ### eval_score: 0.09249
# trial: 0005 ### iterations: 00007 ### eval_score: 0.02601
# trial: 0006 ### iterations: 00004 ### eval_score: 0.04046
# trial: 0007 ### iterations: 00021 ### eval_score: 0.0578
# trial: 0008 ### iterations: 00008 ### eval_score: 0.07225
# trial: 0009 ### iterations: 00032 ### eval_score: 0.03179
# trial: 0010 ### iterations: 00041 ### eval_score: 0.0289
# trial: 0011 ### iterations: 00036 ### eval_score: 0.05202
# trial: 0012 ### iterations: 00020 ### eval_score: 0.06358
# trial: 0013 ### iterations: 00006 ### eval_score: 0.02312
# trial: 0014 ### iterations: 00006 ### eval_score: 0.02023
# trial: 0015 ### iterations: 00016 ### eval_score: 0.04913
# trial: 0016 ### iterations: 00022 ### eval_score: 0.04624
# trial: 0017 ### iterations: 00030 ### eval_score: 0.04624
# trial: 0018 ### iterations: 00039 ### eval_score: 0.03757
# trial: 0019 ### iterations: 00027 ### eval_score: 0.08382
# trial: 0020 ### iterations: 00025 ### eval_score: 0.09249
# trial: 0021 ### iterations: 00004 ### eval_score: 0.03468
# trial: 0022 ### iterations: 00011 ### eval_score: 0.03757
# trial: 0023 ### iterations: 00015 ### eval_score: 0.06936
# trial: 0024 ### iterations: 00015 ### eval_score: 0.06936
# trial: 0025 ### iterations: 00032 ### eval_score: 0.03468
# trial: 0026 ### iterations: 00042 ### eval_score: 0.03179
# trial: 0027 ### iterations: 00036 ### eval_score: 0.05202
# trial: 0028 ### iterations: 00020 ### eval_score: 0.06647
# trial: 0029 ### iterations: 00004 ### eval_score: 0.03179
# trial: 0030 ### iterations: 00010 ### eval_score: 0.0289
# trial: 0031 ### iterations: 00017 ### eval_score: 0.05202
# trial: 0032 ### iterations: 00009 ### eval_score: 0.06069
# trial: 0033 ### iterations: 00038 ### eval_score: 0.04335
# trial: 0034 ### iterations: 00036 ### eval_score: 0.06069
# trial: 0035 ### iterations: 00025 ### eval_score: 0.08959
# trial: 0036 ### iterations: 00025 ### eval_score: 0.09249
# trial: 0037 ### iterations: 00008 ### eval_score: 0.0289
# trial: 0038 ### iterations: 00009 ### eval_score: 0.05202
# trial: 0039 ### iterations: 00028 ### eval_score: 0.0578
# trial: 0040 ### iterations: 00011 ### eval_score: 0.07515
# trial: 0041 ### iterations: 00028 ### eval_score: 0.04335
# trial: 0042 ### iterations: 00038 ### eval_score: 0.04046
# trial: 0043 ### iterations: 00019 ### eval_score: 0.06358
# trial: 0044 ### iterations: 00028 ### eval_score: 0.06647
# trial: 0045 ### iterations: 00011 ### eval_score: 0.0289
# trial: 0046 ### iterations: 00000 ### eval_score: 0.04046
# trial: 0047 ### iterations: 00012 ### eval_score: 0.04913
# trial: 0048 ### iterations: 00015 ### eval_score: 0.05202
# trial: 0049 ### iterations: 00039 ### eval_score: 0.04624
# trial: 0050 ### iterations: 00035 ### eval_score: 0.06647
# trial: 0051 ### iterations: 00025 ### eval_score: 0.08959
# trial: 0052 ### iterations: 00036 ### eval_score: 0.08959
# trial: 0053 ### iterations: 00018 ### eval_score: 0.03757
# trial: 0054 ### iterations: 00017 ### eval_score: 0.05202
# trial: 0055 ### iterations: 00018 ### eval_score: 0.06647
# trial: 0056 ### iterations: 00019 ### eval_score: 0.06936
# trial: 0057 ### iterations: 00034 ### eval_score: 0.04046
# trial: 0058 ### iterations: 00036 ### eval_score: 0.04913
# trial: 0059 ### iterations: 00028 ### eval_score: 0.06069
# trial: 0060 ### iterations: 00023 ### eval_score: 0.06936
# trial: 0061 ### iterations: 00008 ### eval_score: 0.03468
# trial: 0062 ### iterations: 00005 ### eval_score: 0.04335
# trial: 0063 ### iterations: 00018 ### eval_score: 0.04335
# trial: 0064 ### iterations: 00014 ### eval_score: 0.0578
# trial: 0065 ### iterations: 00024 ### eval_score: 0.0578
# trial: 0066 ### iterations: 00024 ### eval_score: 0.0578
# trial: 0067 ### iterations: 00023 ### eval_score: 0.08382
# trial: 0068 ### iterations: 00022 ### eval_score: 0.09538
# trial: 0069 ### iterations: 00007 ### eval_score: 0.02601
# trial: 0070 ### iterations: 00004 ### eval_score: 0.04046
# trial: 0071 ### iterations: 00021 ### eval_score: 0.0578
# trial: 0072 ### iterations: 00008 ### eval_score: 0.07225
# trial: 0073 ### iterations: 00023 ### eval_score: 0.0578
# trial: 0074 ### iterations: 00024 ### eval_score: 0.04624
# trial: 0075 ### iterations: 00023 ### eval_score: 0.06358
# trial: 0076 ### iterations: 00020 ### eval_score: 0.06358
# trial: 0077 ### iterations: 00006 ### eval_score: 0.02312
# trial: 0078 ### iterations: 00006 ### eval_score: 0.02023
# trial: 0079 ### iterations: 00016 ### eval_score: 0.04913
# trial: 0080 ### iterations: 00022 ### eval_score: 0.04624
# trial: 0081 ### iterations: 00024 ### eval_score: 0.0578
# trial: 0082 ### iterations: 00024 ### eval_score: 0.0578
# trial: 0083 ### iterations: 00024 ### eval_score: 0.08671
# trial: 0084 ### iterations: 00024 ### eval_score: 0.09538
# trial: 0085 ### iterations: 00004 ### eval_score: 0.03468
# trial: 0086 ### iterations: 00011 ### eval_score: 0.03757
# trial: 0087 ### iterations: 00015 ### eval_score: 0.06936
# trial: 0088 ### iterations: 00015 ### eval_score: 0.06936
# trial: 0089 ### iterations: 00024 ### eval_score: 0.0578
# trial: 0090 ### iterations: 00024 ### eval_score: 0.05491
# trial: 0091 ### iterations: 00023 ### eval_score: 0.06069
# trial: 0092 ### iterations: 00020 ### eval_score: 0.06647
# trial: 0093 ### iterations: 00004 ### eval_score: 0.03179
# trial: 0094 ### iterations: 00010 ### eval_score: 0.0289
# trial: 0095 ### iterations: 00017 ### eval_score: 0.05202
# trial: 0096 ### iterations: 00009 ### eval_score: 0.06069
# trial: 0097 ### iterations: 00023 ### eval_score: 0.07225
# trial: 0098 ### iterations: 00024 ### eval_score: 0.08092
# trial: 0099 ### iterations: 00023 ### eval_score: 0.09249
# trial: 0100 ### iterations: 00023 ### eval_score: 0.09538
# trial: 0101 ### iterations: 00008 ### eval_score: 0.0289
# trial: 0102 ### iterations: 00009 ### eval_score: 0.05202
# trial: 0103 ### iterations: 00023 ### eval_score: 0.06358
# trial: 0104 ### iterations: 00011 ### eval_score: 0.07515
# trial: 0105 ### iterations: 00024 ### eval_score: 0.0578
# trial: 0106 ### iterations: 00024 ### eval_score: 0.06358
# trial: 0107 ### iterations: 00019 ### eval_score: 0.06358
# trial: 0108 ### iterations: 00023 ### eval_score: 0.07225
# trial: 0109 ### iterations: 00011 ### eval_score: 0.0289
# trial: 0110 ### iterations: 00000 ### eval_score: 0.04046
# trial: 0111 ### iterations: 00012 ### eval_score: 0.04913
# trial: 0112 ### iterations: 00015 ### eval_score: 0.05202
# trial: 0113 ### iterations: 00024 ### eval_score: 0.07225
# trial: 0114 ### iterations: 00024 ### eval_score: 0.08092
# trial: 0115 ### iterations: 00024 ### eval_score: 0.09538
# trial: 0116 ### iterations: 00022 ### eval_score: 0.10405
# trial: 0117 ### iterations: 00018 ### eval_score: 0.03757
# trial: 0118 ### iterations: 00017 ### eval_score: 0.05202
# trial: 0119 ### iterations: 00018 ### eval_score: 0.06647
# trial: 0120 ### iterations: 00019 ### eval_score: 0.06936
# trial: 0121 ### iterations: 00024 ### eval_score: 0.06069
# trial: 0122 ### iterations: 00022 ### eval_score: 0.06936
# trial: 0123 ### iterations: 00019 ### eval_score: 0.06647
# trial: 0124 ### iterations: 00023 ### eval_score: 0.06936
# trial: 0125 ### iterations: 00008 ### eval_score: 0.03468
# trial: 0126 ### iterations: 00005 ### eval_score: 0.04335
# trial: 0127 ### iterations: 00018 ### eval_score: 0.04335
# trial: 0128 ### iterations: 00014 ### eval_score: 0.0578
# trial: 0129 ### iterations: 00001 ### eval_score: 0.18208
# trial: 0130 ### iterations: 00001 ### eval_score: 0.1763
# trial: 0131 ### iterations: 00000 ### eval_score: 0.19653
# trial: 0132 ### iterations: 00000 ### eval_score: 0.19653
# trial: 0133 ### iterations: 00004 ### eval_score: 0.02601
# trial: 0134 ### iterations: 00004 ### eval_score: 0.03179
# trial: 0135 ### iterations: 00000 ### eval_score: 0.13006
# trial: 0136 ### iterations: 00000 ### eval_score: 0.13006
# trial: 0137 ### iterations: 00000 ### eval_score: 0.21098
# trial: 0138 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0139 ### iterations: 00000 ### eval_score: 0.21098
# trial: 0140 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0141 ### iterations: 00003 ### eval_score: 0.02312
# trial: 0142 ### iterations: 00003 ### eval_score: 0.02023
# trial: 0143 ### iterations: 00000 ### eval_score: 0.09249
# trial: 0144 ### iterations: 00000 ### eval_score: 0.09249
# trial: 0145 ### iterations: 00001 ### eval_score: 0.20231
# trial: 0146 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0147 ### iterations: 00000 ### eval_score: 0.19653
# trial: 0148 ### iterations: 00001 ### eval_score: 0.19075
# trial: 0149 ### iterations: 00004 ### eval_score: 0.04335
# trial: 0150 ### iterations: 00009 ### eval_score: 0.04046
# trial: 0151 ### iterations: 00001 ### eval_score: 0.12428
# trial: 0152 ### iterations: 00001 ### eval_score: 0.12428
# trial: 0153 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0154 ### iterations: 00000 ### eval_score: 0.19653
# trial: 0155 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0156 ### iterations: 00000 ### eval_score: 0.19653
# trial: 0157 ### iterations: 00004 ### eval_score: 0.04335
# trial: 0158 ### iterations: 00000 ### eval_score: 0.04913
# trial: 0159 ### iterations: 00000 ### eval_score: 0.08959
# trial: 0160 ### iterations: 00000 ### eval_score: 0.08959
# trial: 0161 ### iterations: 00001 ### eval_score: 0.20231
# trial: 0162 ### iterations: 00001 ### eval_score: 0.18786
# trial: 0163 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0164 ### iterations: 00001 ### eval_score: 0.19942
# trial: 0165 ### iterations: 00000 ### eval_score: 0.04913
# trial: 0166 ### iterations: 00000 ### eval_score: 0.05491
# trial: 0167 ### iterations: 00000 ### eval_score: 0.12428
# trial: 0168 ### iterations: 00003 ### eval_score: 0.12717
# trial: 0169 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0170 ### iterations: 00000 ### eval_score: 0.19942
# trial: 0171 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0172 ### iterations: 00000 ### eval_score: 0.19942
# trial: 0173 ### iterations: 00002 ### eval_score: 0.04046
# trial: 0174 ### iterations: 00000 ### eval_score: 0.04046
# trial: 0175 ### iterations: 00000 ### eval_score: 0.08959
# trial: 0176 ### iterations: 00000 ### eval_score: 0.08671
# trial: 0177 ### iterations: 00001 ### eval_score: 0.19364
# trial: 0178 ### iterations: 00001 ### eval_score: 0.19942
# trial: 0179 ### iterations: 00000 ### eval_score: 0.19942
# trial: 0180 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0181 ### iterations: 00011 ### eval_score: 0.06069
# trial: 0182 ### iterations: 00007 ### eval_score: 0.06358
# trial: 0183 ### iterations: 00001 ### eval_score: 0.12428
# trial: 0184 ### iterations: 00001 ### eval_score: 0.12428
# trial: 0185 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0186 ### iterations: 00000 ### eval_score: 0.19942
# trial: 0187 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0188 ### iterations: 00000 ### eval_score: 0.19942
# trial: 0189 ### iterations: 00003 ### eval_score: 0.05202
# trial: 0190 ### iterations: 00004 ### eval_score: 0.05202
# trial: 0191 ### iterations: 00000 ### eval_score: 0.08959
# trial: 0192 ### iterations: 00000 ### eval_score: 0.08671
# trial: 0193 ### iterations: 00001 ### eval_score: 0.18208
# trial: 0194 ### iterations: 00001 ### eval_score: 0.1763
# trial: 0195 ### iterations: 00000 ### eval_score: 0.19653
# trial: 0196 ### iterations: 00000 ### eval_score: 0.19653
# trial: 0197 ### iterations: 00004 ### eval_score: 0.02601
# trial: 0198 ### iterations: 00004 ### eval_score: 0.03179
# trial: 0199 ### iterations: 00000 ### eval_score: 0.13006
# trial: 0200 ### iterations: 00000 ### eval_score: 0.13006
# trial: 0201 ### iterations: 00000 ### eval_score: 0.21098
# trial: 0202 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0203 ### iterations: 00000 ### eval_score: 0.21098
# trial: 0204 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0205 ### iterations: 00003 ### eval_score: 0.02312
# trial: 0206 ### iterations: 00003 ### eval_score: 0.02023
# trial: 0207 ### iterations: 00000 ### eval_score: 0.09249
# trial: 0208 ### iterations: 00000 ### eval_score: 0.09249
# trial: 0209 ### iterations: 00001 ### eval_score: 0.20231
# trial: 0210 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0211 ### iterations: 00000 ### eval_score: 0.19653
# trial: 0212 ### iterations: 00001 ### eval_score: 0.19075
# trial: 0213 ### iterations: 00004 ### eval_score: 0.04335
# trial: 0214 ### iterations: 00009 ### eval_score: 0.04046
# trial: 0215 ### iterations: 00001 ### eval_score: 0.12428
# trial: 0216 ### iterations: 00001 ### eval_score: 0.12428
# trial: 0217 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0218 ### iterations: 00000 ### eval_score: 0.19653
# trial: 0219 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0220 ### iterations: 00000 ### eval_score: 0.19653
# trial: 0221 ### iterations: 00004 ### eval_score: 0.04335
# trial: 0222 ### iterations: 00000 ### eval_score: 0.04913
# trial: 0223 ### iterations: 00000 ### eval_score: 0.08959
# trial: 0224 ### iterations: 00000 ### eval_score: 0.08959
# trial: 0225 ### iterations: 00001 ### eval_score: 0.20231
# trial: 0226 ### iterations: 00001 ### eval_score: 0.18786
# trial: 0227 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0228 ### iterations: 00001 ### eval_score: 0.19942
# trial: 0229 ### iterations: 00000 ### eval_score: 0.04913
# trial: 0230 ### iterations: 00000 ### eval_score: 0.05491
# trial: 0231 ### iterations: 00000 ### eval_score: 0.12428
# trial: 0232 ### iterations: 00003 ### eval_score: 0.12717
# trial: 0233 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0234 ### iterations: 00000 ### eval_score: 0.19942
# trial: 0235 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0236 ### iterations: 00000 ### eval_score: 0.19942
# trial: 0237 ### iterations: 00002 ### eval_score: 0.04046
# trial: 0238 ### iterations: 00000 ### eval_score: 0.04046
# trial: 0239 ### iterations: 00000 ### eval_score: 0.08959
# trial: 0240 ### iterations: 00000 ### eval_score: 0.08671
# trial: 0241 ### iterations: 00001 ### eval_score: 0.19364
# trial: 0242 ### iterations: 00001 ### eval_score: 0.19942
# trial: 0243 ### iterations: 00000 ### eval_score: 0.19942
# trial: 0244 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0245 ### iterations: 00011 ### eval_score: 0.06069
# trial: 0246 ### iterations: 00007 ### eval_score: 0.06358
# trial: 0247 ### iterations: 00001 ### eval_score: 0.12428
# trial: 0248 ### iterations: 00001 ### eval_score: 0.12428
# trial: 0249 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0250 ### iterations: 00000 ### eval_score: 0.19942
# trial: 0251 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0252 ### iterations: 00000 ### eval_score: 0.19942
# trial: 0253 ### iterations: 00003 ### eval_score: 0.05202
# trial: 0254 ### iterations: 00004 ### eval_score: 0.05202
# trial: 0255 ### iterations: 00000 ### eval_score: 0.08959
# trial: 0256 ### iterations: 00000 ### eval_score: 0.08671
# trial: 0257 ### iterations: 00042 ### eval_score: 0.0289
# trial: 0258 ### iterations: 00024 ### eval_score: 0.05202
# trial: 0259 ### iterations: 00027 ### eval_score: 0.07803
# trial: 0260 ### iterations: 00028 ### eval_score: 0.08959
# trial: 0261 ### iterations: 00025 ### eval_score: 0.01445
# trial: 0262 ### iterations: 00011 ### eval_score: 0.04046
# trial: 0263 ### iterations: 00016 ### eval_score: 0.0578
# trial: 0264 ### iterations: 00019 ### eval_score: 0.0578
# trial: 0265 ### iterations: 00030 ### eval_score: 0.03757
# trial: 0266 ### iterations: 00037 ### eval_score: 0.03468
# trial: 0267 ### iterations: 00028 ### eval_score: 0.05202
# trial: 0268 ### iterations: 00020 ### eval_score: 0.06069
# trial: 0269 ### iterations: 00028 ### eval_score: 0.00867
# trial: 0270 ### iterations: 00027 ### eval_score: 0.02312
# trial: 0271 ### iterations: 00021 ### eval_score: 0.04913
# trial: 0272 ### iterations: 00019 ### eval_score: 0.05202
# trial: 0273 ### iterations: 00013 ### eval_score: 0.13295
# trial: 0274 ### iterations: 00042 ### eval_score: 0.07225
# trial: 0275 ### iterations: 00025 ### eval_score: 0.08671
# trial: 0276 ### iterations: 00028 ### eval_score: 0.08959
# trial: 0277 ### iterations: 00025 ### eval_score: 0.01734
# trial: 0278 ### iterations: 00011 ### eval_score: 0.04913
# trial: 0279 ### iterations: 00021 ### eval_score: 0.06069
# trial: 0280 ### iterations: 00025 ### eval_score: 0.0578
# trial: 0281 ### iterations: 00030 ### eval_score: 0.03757
# trial: 0282 ### iterations: 00037 ### eval_score: 0.03757
# trial: 0283 ### iterations: 00033 ### eval_score: 0.05491
# trial: 0284 ### iterations: 00020 ### eval_score: 0.06647
# trial: 0285 ### iterations: 00023 ### eval_score: 0.0578
# trial: 0286 ### iterations: 00025 ### eval_score: 0.0289
# trial: 0287 ### iterations: 00022 ### eval_score: 0.04624
# trial: 0288 ### iterations: 00018 ### eval_score: 0.05202
# trial: 0289 ### iterations: 00036 ### eval_score: 0.04335
# trial: 0290 ### iterations: 00041 ### eval_score: 0.06069
# trial: 0291 ### iterations: 00025 ### eval_score: 0.08959
# trial: 0292 ### iterations: 00025 ### eval_score: 0.09249
# trial: 0293 ### iterations: 00036 ### eval_score: 0.02023
# trial: 0294 ### iterations: 00023 ### eval_score: 0.06069
# trial: 0295 ### iterations: 00021 ### eval_score: 0.06358
# trial: 0296 ### iterations: 00003 ### eval_score: 0.09249
# trial: 0297 ### iterations: 00036 ### eval_score: 0.03468
# trial: 0298 ### iterations: 00024 ### eval_score: 0.0578
# trial: 0299 ### iterations: 00019 ### eval_score: 0.06647
# trial: 0300 ### iterations: 00034 ### eval_score: 0.05491
# trial: 0301 ### iterations: 00033 ### eval_score: 0.01445
# trial: 0302 ### iterations: 00025 ### eval_score: 0.03757
# trial: 0303 ### iterations: 00021 ### eval_score: 0.05202
# trial: 0304 ### iterations: 00017 ### eval_score: 0.05491
# trial: 0305 ### iterations: 00038 ### eval_score: 0.04913
# trial: 0306 ### iterations: 00035 ### eval_score: 0.07225
# trial: 0307 ### iterations: 00027 ### eval_score: 0.08959
# trial: 0308 ### iterations: 00036 ### eval_score: 0.08959
# trial: 0309 ### iterations: 00017 ### eval_score: 0.0578
# trial: 0310 ### iterations: 00025 ### eval_score: 0.0578
# trial: 0311 ### iterations: 00025 ### eval_score: 0.06358
# trial: 0312 ### iterations: 00018 ### eval_score: 0.07225
# trial: 0313 ### iterations: 00037 ### eval_score: 0.03757
# trial: 0314 ### iterations: 00024 ### eval_score: 0.06069
# trial: 0315 ### iterations: 00034 ### eval_score: 0.05491
# trial: 0316 ### iterations: 00039 ### eval_score: 0.0578
# trial: 0317 ### iterations: 00041 ### eval_score: 0.01445
# trial: 0318 ### iterations: 00019 ### eval_score: 0.04624
# trial: 0319 ### iterations: 00025 ### eval_score: 0.04335
# trial: 0320 ### iterations: 00009 ### eval_score: 0.07225
# trial: 0321 ### iterations: 00024 ### eval_score: 0.05202
# trial: 0322 ### iterations: 00024 ### eval_score: 0.05202
# trial: 0323 ### iterations: 00024 ### eval_score: 0.08382
# trial: 0324 ### iterations: 00023 ### eval_score: 0.09538
# trial: 0325 ### iterations: 00024 ### eval_score: 0.02023
# trial: 0326 ### iterations: 00011 ### eval_score: 0.04046
# trial: 0327 ### iterations: 00016 ### eval_score: 0.0578
# trial: 0328 ### iterations: 00019 ### eval_score: 0.0578
# trial: 0329 ### iterations: 00023 ### eval_score: 0.04624
# trial: 0330 ### iterations: 00023 ### eval_score: 0.0578
# trial: 0331 ### iterations: 00024 ### eval_score: 0.06069
# trial: 0332 ### iterations: 00020 ### eval_score: 0.06069
# trial: 0333 ### iterations: 00024 ### eval_score: 0.01156
# trial: 0334 ### iterations: 00021 ### eval_score: 0.02601
# trial: 0335 ### iterations: 00021 ### eval_score: 0.04913
# trial: 0336 ### iterations: 00019 ### eval_score: 0.05202
# trial: 0337 ### iterations: 00013 ### eval_score: 0.13295
# trial: 0338 ### iterations: 00024 ### eval_score: 0.10405
# trial: 0339 ### iterations: 00022 ### eval_score: 0.08959
# trial: 0340 ### iterations: 00023 ### eval_score: 0.09538
# trial: 0341 ### iterations: 00024 ### eval_score: 0.02023
# trial: 0342 ### iterations: 00011 ### eval_score: 0.04913
# trial: 0343 ### iterations: 00021 ### eval_score: 0.06069
# trial: 0344 ### iterations: 00021 ### eval_score: 0.06358
# trial: 0345 ### iterations: 00023 ### eval_score: 0.04913
# trial: 0346 ### iterations: 00023 ### eval_score: 0.0578
# trial: 0347 ### iterations: 00024 ### eval_score: 0.06069
# trial: 0348 ### iterations: 00020 ### eval_score: 0.06647
# trial: 0349 ### iterations: 00023 ### eval_score: 0.0578
# trial: 0350 ### iterations: 00024 ### eval_score: 0.03468
# trial: 0351 ### iterations: 00022 ### eval_score: 0.04624
# trial: 0352 ### iterations: 00018 ### eval_score: 0.05202
# trial: 0353 ### iterations: 00024 ### eval_score: 0.06358
# trial: 0354 ### iterations: 00023 ### eval_score: 0.08092
# trial: 0355 ### iterations: 00022 ### eval_score: 0.09249
# trial: 0356 ### iterations: 00023 ### eval_score: 0.09538
# trial: 0357 ### iterations: 00024 ### eval_score: 0.04335
# trial: 0358 ### iterations: 00023 ### eval_score: 0.06069
# trial: 0359 ### iterations: 00021 ### eval_score: 0.06358
# trial: 0360 ### iterations: 00003 ### eval_score: 0.09249
# trial: 0361 ### iterations: 00024 ### eval_score: 0.05491
# trial: 0362 ### iterations: 00024 ### eval_score: 0.0578
# trial: 0363 ### iterations: 00019 ### eval_score: 0.06647
# trial: 0364 ### iterations: 00024 ### eval_score: 0.07225
# trial: 0365 ### iterations: 00022 ### eval_score: 0.03179
# trial: 0366 ### iterations: 00024 ### eval_score: 0.04335
# trial: 0367 ### iterations: 00021 ### eval_score: 0.05202
# trial: 0368 ### iterations: 00017 ### eval_score: 0.05491
# trial: 0369 ### iterations: 00023 ### eval_score: 0.07515
# trial: 0370 ### iterations: 00024 ### eval_score: 0.08382
# trial: 0371 ### iterations: 00024 ### eval_score: 0.09538
# trial: 0372 ### iterations: 00022 ### eval_score: 0.10405
# trial: 0373 ### iterations: 00017 ### eval_score: 0.0578
# trial: 0374 ### iterations: 00024 ### eval_score: 0.06069
# trial: 0375 ### iterations: 00024 ### eval_score: 0.06647
# trial: 0376 ### iterations: 00018 ### eval_score: 0.07225
# trial: 0377 ### iterations: 00024 ### eval_score: 0.0578
# trial: 0378 ### iterations: 00024 ### eval_score: 0.06069
# trial: 0379 ### iterations: 00022 ### eval_score: 0.06647
# trial: 0380 ### iterations: 00023 ### eval_score: 0.07225
# trial: 0381 ### iterations: 00023 ### eval_score: 0.04046
# trial: 0382 ### iterations: 00019 ### eval_score: 0.04624
# trial: 0383 ### iterations: 00021 ### eval_score: 0.04624
# trial: 0384 ### iterations: 00009 ### eval_score: 0.07225
# trial: 0385 ### iterations: 00001 ### eval_score: 0.19653
# trial: 0386 ### iterations: 00001 ### eval_score: 0.18786
# trial: 0387 ### iterations: 00001 ### eval_score: 0.19653
# trial: 0388 ### iterations: 00001 ### eval_score: 0.19653
# trial: 0389 ### iterations: 00000 ### eval_score: 0.11272
# trial: 0390 ### iterations: 00000 ### eval_score: 0.11272
# trial: 0391 ### iterations: 00000 ### eval_score: 0.13006
# trial: 0392 ### iterations: 00000 ### eval_score: 0.13006
# trial: 0393 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0394 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0395 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0396 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0397 ### iterations: 00000 ### eval_score: 0.09538
# trial: 0398 ### iterations: 00000 ### eval_score: 0.09538
# trial: 0399 ### iterations: 00000 ### eval_score: 0.10694
# trial: 0400 ### iterations: 00000 ### eval_score: 0.10694
# trial: 0401 ### iterations: 00000 ### eval_score: 0.20809
# trial: 0402 ### iterations: 00001 ### eval_score: 0.1763
# trial: 0403 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0404 ### iterations: 00001 ### eval_score: 0.1763
# trial: 0405 ### iterations: 00000 ### eval_score: 0.11272
# trial: 0406 ### iterations: 00000 ### eval_score: 0.11272
# trial: 0407 ### iterations: 00002 ### eval_score: 0.12717
# trial: 0408 ### iterations: 00000 ### eval_score: 0.12717
# trial: 0409 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0410 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0411 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0412 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0413 ### iterations: 00000 ### eval_score: 0.09249
# trial: 0414 ### iterations: 00000 ### eval_score: 0.09249
# trial: 0415 ### iterations: 00000 ### eval_score: 0.10405
# trial: 0416 ### iterations: 00000 ### eval_score: 0.10405
# trial: 0417 ### iterations: 00001 ### eval_score: 0.20231
# trial: 0418 ### iterations: 00001 ### eval_score: 0.19653
# trial: 0419 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0420 ### iterations: 00001 ### eval_score: 0.19942
# trial: 0421 ### iterations: 00000 ### eval_score: 0.11272
# trial: 0422 ### iterations: 00000 ### eval_score: 0.11272
# trial: 0423 ### iterations: 00000 ### eval_score: 0.12428
# trial: 0424 ### iterations: 00002 ### eval_score: 0.13295
# trial: 0425 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0426 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0427 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0428 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0429 ### iterations: 00000 ### eval_score: 0.08959
# trial: 0430 ### iterations: 00000 ### eval_score: 0.08671
# trial: 0431 ### iterations: 00000 ### eval_score: 0.10405
# trial: 0432 ### iterations: 00000 ### eval_score: 0.10116
# trial: 0433 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0434 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0435 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0436 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0437 ### iterations: 00003 ### eval_score: 0.12717
# trial: 0438 ### iterations: 00003 ### eval_score: 0.12717
# trial: 0439 ### iterations: 00002 ### eval_score: 0.13295
# trial: 0440 ### iterations: 00002 ### eval_score: 0.13295
# trial: 0441 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0442 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0443 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0444 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0445 ### iterations: 00000 ### eval_score: 0.08959
# trial: 0446 ### iterations: 00000 ### eval_score: 0.08671
# trial: 0447 ### iterations: 00000 ### eval_score: 0.10405
# trial: 0448 ### iterations: 00000 ### eval_score: 0.10116
# trial: 0449 ### iterations: 00001 ### eval_score: 0.19653
# trial: 0450 ### iterations: 00001 ### eval_score: 0.18786
# trial: 0451 ### iterations: 00001 ### eval_score: 0.19653
# trial: 0452 ### iterations: 00001 ### eval_score: 0.19653
# trial: 0453 ### iterations: 00000 ### eval_score: 0.11272
# trial: 0454 ### iterations: 00000 ### eval_score: 0.11272
# trial: 0455 ### iterations: 00000 ### eval_score: 0.13006
# trial: 0456 ### iterations: 00000 ### eval_score: 0.13006
# trial: 0457 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0458 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0459 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0460 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0461 ### iterations: 00000 ### eval_score: 0.09538
# trial: 0462 ### iterations: 00000 ### eval_score: 0.09538
# trial: 0463 ### iterations: 00000 ### eval_score: 0.10694
# trial: 0464 ### iterations: 00000 ### eval_score: 0.10694
# trial: 0465 ### iterations: 00000 ### eval_score: 0.20809
# trial: 0466 ### iterations: 00001 ### eval_score: 0.1763
# trial: 0467 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0468 ### iterations: 00001 ### eval_score: 0.1763
# trial: 0469 ### iterations: 00000 ### eval_score: 0.11272
# trial: 0470 ### iterations: 00000 ### eval_score: 0.11272
# trial: 0471 ### iterations: 00002 ### eval_score: 0.12717
# trial: 0472 ### iterations: 00000 ### eval_score: 0.12717
# trial: 0473 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0474 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0475 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0476 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0477 ### iterations: 00000 ### eval_score: 0.09249
# trial: 0478 ### iterations: 00000 ### eval_score: 0.09249
# trial: 0479 ### iterations: 00000 ### eval_score: 0.10405
# trial: 0480 ### iterations: 00000 ### eval_score: 0.10405
# trial: 0481 ### iterations: 00001 ### eval_score: 0.20231
# trial: 0482 ### iterations: 00001 ### eval_score: 0.19653
# trial: 0483 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0484 ### iterations: 00001 ### eval_score: 0.19942
# trial: 0485 ### iterations: 00000 ### eval_score: 0.11272
# trial: 0486 ### iterations: 00000 ### eval_score: 0.11272
# trial: 0487 ### iterations: 00000 ### eval_score: 0.12428
# trial: 0488 ### iterations: 00002 ### eval_score: 0.13295
# trial: 0489 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0490 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0491 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0492 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0493 ### iterations: 00000 ### eval_score: 0.08959
# trial: 0494 ### iterations: 00000 ### eval_score: 0.08671
# trial: 0495 ### iterations: 00000 ### eval_score: 0.10405
# trial: 0496 ### iterations: 00000 ### eval_score: 0.10116
# trial: 0497 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0498 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0499 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0500 ### iterations: 00000 ### eval_score: 0.2052
# trial: 0501 ### iterations: 00003 ### eval_score: 0.12717
# trial: 0502 ### iterations: 00003 ### eval_score: 0.12717
# trial: 0503 ### iterations: 00002 ### eval_score: 0.13295
# trial: 0504 ### iterations: 00002 ### eval_score: 0.13295
# trial: 0505 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0506 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0507 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0508 ### iterations: 00000 ### eval_score: 0.19075
# trial: 0509 ### iterations: 00000 ### eval_score: 0.08959
# trial: 0510 ### iterations: 00000 ### eval_score: 0.08671
# trial: 0511 ### iterations: 00000 ### eval_score: 0.10405
# trial: 0512 ### iterations: 00000 ### eval_score: 0.10116

# %%
test_eval(xclf, X_test, y_test, 'XGB')
# Out:
# Confusion Matrix
# ============================================================
# [[240   2   0   0]
#  [  0  77   0   0]
#  [  0   0  13   1]
#  [  0   0   0  13]]
#
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       242
#            1       0.97      1.00      0.99        77
#            2       1.00      0.93      0.96        14
#            3       0.93      1.00      0.96        13
#
#     accuracy                           0.99       346
#    macro avg       0.98      0.98      0.98       346
# weighted avg       0.99      0.99      0.99       346
#
#
# ============================================================
# AUC-ROC
# 0.9994053235107178
#
# Balanced Accuracy
# 0.9800767414403778
#
# Geometric Mean Score
# 0.988695728781396
#
# Sensitivity
# 0.9800767414403778
#
# Specificity
# 0.9973905131897698

# %% [markdown]
# # MODEL-7 Stacking

# %%
clf_DT = DecisionTreeClassifier()
clf_SVC = SVC(probability=True)
clf_KNN = KNeighborsClassifier()
clf_LR = LogisticRegression()

sclf = StackingClassifier(classifiers=[clf_DT, clf_SVC, clf_KNN], use_probas=True, average_probas=False, meta_classifier=clf_LR)

# %%
sclf.fit(X_train, y_train)
test_eval(sclf, X_test, y_test, 'Stacking')
# Out:
# Confusion Matrix
# ============================================================
# [[239   2   1   0]
#  [  2  74   1   0]
#  [  0   3  11   0]
#  [  0   0   0  13]]
#
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       242
#            1       0.94      0.96      0.95        77
#            2       0.85      0.79      0.81        14
#            3       1.00      1.00      1.00        13
#
#     accuracy                           0.97       346
#    macro avg       0.94      0.93      0.94       346
# weighted avg       0.97      0.97      0.97       346
#
#
# ============================================================
# AUC-ROC
# 0.997710928758412
#
# Balanced Accuracy
# 0.9335891381345927
#
# Geometric Mean Score
# 0.960914398679201
#
# Sensitivity
# 0.9335891381345927
#
# Specificity
# 0.9890394434472233

# %% [markdown]
# # MODEL-8 Bagging

# %%
clf_bg = BaggingClassifier(clf_DT)

# %%
clf_bg.fit(X_train, y_train)
test_eval(clf_bg, X_test, y_test, 'Bagging')
# Out:
# Confusion Matrix
# ============================================================
# [[239   2   1   0]
#  [  1  74   2   0]
#  [  0   0  13   1]
#  [  0   0   0  13]]
#
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       242
#            1       0.97      0.96      0.97        77
#            2       0.81      0.93      0.87        14
#            3       0.93      1.00      0.96        13
#
#     accuracy                           0.98       346
#    macro avg       0.93      0.97      0.95       346
# weighted avg       0.98      0.98      0.98       346
#
#
# ============================================================
# AUC-ROC
# 0.9986689269863918
#
# Balanced Accuracy
# 0.9693034238488785
#
# Geometric Mean Score
# 0.980945610914472
#
# Sensitivity
# 0.9693034238488785
#
# Specificity
# 0.9927276308913453

# %%
clf_eval_df = pd.DataFrame({'model':model,
                            'precision':precision,
                            'recall':recall,
                            'f1-score':F1score,
                            'AUC-ROC':AUCROC,
                            'balanced_acc':balanced_acc,
                            'GMean':GMean,
                            'sensitivity':sensi,
                            'specificity':speci})
clf_eval_df
# Out:
#                  model  precision    recall  f1-score   AUC-ROC  balanced_acc  \
# 0  Logistic Regression   0.859585  0.450061  0.475530  0.941429      0.450061
# 1        Decision Tree   0.928328  0.930342  0.929324  0.959314      0.930342
# 2          Gaussian NB   0.401867  0.517119  0.364037  0.870346      0.517119
# 3                  KNN   0.967126  0.876237  0.913690  0.995972      0.876237
# 4                  SVC   0.934161  0.882038  0.897350  0.997895      0.882038
# 5                  XGB   0.975814  0.980077  0.977239  0.999405      0.980077
# 6             Stacking   0.943641  0.933589  0.938295  0.997711      0.933589
# 7              Bagging   0.927647  0.969303  0.947163  0.998669      0.969303
#
#       GMean  sensitivity  specificity
# 0  0.634523     0.450061     0.894588
# 1  0.958877     0.930342     0.988286
# 2  0.671891     0.517119     0.872986
# 3  0.928318     0.876237     0.983495
# 4  0.932950     0.882038     0.986801
# 5  0.988696     0.980077     0.997391
# 6  0.960914     0.933589     0.989039
# 7  0.980946     0.969303     0.992728

# %%
clf_eval_df.to_excel("D:\Skripsi\Final\project_car_final.xlsx")
